# %%
import pandas as pd
import numpy as np
import os
import csv

# %%
csvpath = os.path.join('.', 'Resources', 'pH_soil_Project_5.csv')

# %%
file_pH = pd.read_csv(csvpath, low_memory=False)

# %%
file_pH = file_pH.fillna(0)

# %%
file_pH_df = file_pH.loc[file_pH["country_name"] == "United States of America", :]
file_pH_df
# Out:
#                  X          Y  profile_id  profile_layer_id  \
# 35848  -142.470001  63.462002      614288           3134507
# 35849  -142.470001  63.462002      614288           3134508
# 35850  -147.477997  65.153000      614298           3134558
# 35851  -147.477997  65.153000      614298           3134560
# 35852  -147.477997  65.153000      614298           3134561
# ...            ...        ...         ...               ...
# 456572  -92.016667  46.686944      232348           1132773
# 456573  -92.016667  46.686944      232348           1132774
# 456574  -92.016667  46.686944      232348           1132775
# 456575  -92.016667  46.686944      232348           1132776
# 456576  -92.016667  46.686944      232348           1132777
#
#                     country_name  upper_depth  lower_depth layer_name  litter  \
# 35848   United States of America         15.0         20.0          0       0
# 35849   United States of America         20.0         25.0          0       0
# ...
