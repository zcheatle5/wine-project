# %%
import pandas as pd
import numpy as np
import os
import csv

# %%
csvpath = os.path.join('.', 'Resources', 'pH_soil_Project_5.csv')

# %%
file_pH = pd.read_csv(csvpath, low_memory=False)

# %%
file_pH
# Out:
#                X          Y  profile_id  profile_layer_id country_name  \
# 0       7.686285  47.387739      545456           2978124  Switzerland
# 1       7.686285  47.387739      545456           2978125  Switzerland
# 2       7.686285  47.387739      545456           2978127  Switzerland
# 3       7.686285  47.387739      545456           2978128  Switzerland
# 4       7.686285  47.387739      545456           2978129  Switzerland
# ...          ...        ...         ...               ...          ...
# 610491  7.788991  47.417919      545455           2978118  Switzerland
# 610492  7.788991  47.417919      545455           2978119  Switzerland
# 610493  7.788991  47.417919      545455           2978120  Switzerland
# 610494  7.788991  47.417919      545455           2978121  Switzerland
# 610495  7.788991  47.417919      545455           2978122  Switzerland
#
#         upper_depth  lower_depth layer_name  litter phaq_value  \
# ...
